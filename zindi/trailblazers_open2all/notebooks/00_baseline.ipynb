# %% [markdown]
# <a href="https://colab.research.google.com/github/stiwari-ds/data-science-competitions/blob/main/zindi/trailblazers_open2all/notebooks/00_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
import gc
import os
import warnings

gc.enable()
warnings.filterwarnings(action='ignore')

import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 4)
np.set_printoptions(precision=4)

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import make_pipeline

from google.colab import drive

SEED = 23
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_PATH = '/content/drive/MyDrive/data_science_competitions/zindi/trailblazers_open2all/data'
train = pd.read_csv(f'{DATA_PATH}/raw/train.csv')
test = pd.read_csv(f'{DATA_PATH}/raw/test.csv')
sample_sub = pd.read_csv(f'{DATA_PATH}/raw/sample_sub.csv')

# %%
NOTEBOOK = '00'
SUBMISSION_PATH = f'/content/drive/MyDrive/data_science_competitions/zindi/trailblazers_open2all/submissions/nb_{NOTEBOOK}'
if not os.path.isdir(SUBMISSION_PATH):
    os.mkdir(SUBMISSION_PATH)

# %% [markdown]
# # Data overview

# %%
train.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0           769.50            92                               11.0000
# 1          1319.85            91                               14.6000
# 2          1181.96            96                               16.4000
# 3          1113.67            96                                6.9119
# 4          1164.82            95                               13.9000
#
#    relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 0                               60.2                             0.0080
# 1                               48.8                             0.0084
# 2                               33.4                             0.0075
# 3                               21.3                             0.0039
# 4                               44.7                             0.0053
#
#    temperature_2m_above_ground  u_component_of_wind_10m_above_ground  \
# 0                      18.5168                                1.9964
# 1                      22.5465                                3.3304
# 2                      27.0310                                5.0657
# 3                      23.9719                                3.0040
# 4                      16.8163                                2.6218
#
#    v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density  \
# 0                               -1.2274                        7.3830e-05
# 1                               -1.1881                        7.6033e-05
# 2                                3.5006                        6.6608e-05
# 3                                1.0995                        8.2582e-05
# 4                                2.6706                        7.0385e-05
#
#    L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index  \
# 0                                  0.0002                         -1.2313
# 1                                  0.0002                         -1.0826
# 2                                  0.0002                         -1.0012
# 3                                  0.0002                         -0.7770
# 4                                  0.0001                          0.3663
#
#    L3_NO2_cloud_fraction  L3_NO2_sensor_altitude  L3_NO2_sensor_azimuth_angle  \
# 0                 0.0065             840209.8746                      76.5375
# 1                 0.0184             840772.9420                     -14.7080
# 2                 0.0159             841410.7135                    -105.2013
# 3                 0.0558             841103.2424                    -104.3341
# 4                 0.0285             840763.0555                      58.8502
#
#    L3_NO2_sensor_zenith_angle  L3_NO2_solar_azimuth_angle  \
# 0                     38.6343                    -61.7367
# 1                     59.6249                    -67.6935
# 2                     49.8397                    -78.3427
# 3                     29.1810                    -73.8966
# 4                      0.7973                    -68.6125
#
#    L3_NO2_solar_zenith_angle  L3_NO2_stratospheric_NO2_column_number_density  \
# 0                    22.3582                                      5.6793e-05
# 1                    28.6148                                      5.4651e-05
# 2                    34.2970                                      5.9126e-05
# 3                    30.5454                                      5.9539e-05
# 4                    26.8997                                      6.1640e-05
#
#    L3_NO2_tropopause_pressure  L3_NO2_tropospheric_NO2_column_number_density  \
# 0                   6156.0742                                     1.7038e-05
# 1                   6156.0742                                     2.1381e-05
# 2                   7311.8691                                     7.4820e-06
# 3                  11205.3883                                     2.3025e-05
# 4                  11205.3728                                     8.7448e-06
#
#    L3_O3_O3_column_number_density  L3_O3_O3_effective_temperature  \
# 0                          0.1191                        234.1511
# 1                          0.1152                        233.3137
# 2                          0.1159                        232.2335
# 3                          0.1416                        230.9362
# 4                          0.1264                        232.4991
#
#    L3_O3_cloud_fraction  L3_O3_sensor_azimuth_angle  \
# 0                0.0000                     76.5364
# 1                0.0594                    -14.7080
# 2                0.0821                   -105.2013
# 3                0.1213                   -104.3341
# 4                0.0379                     58.8502
#
#    L3_O3_sensor_zenith_angle  L3_O3_solar_azimuth_angle  \
# 0                    38.5930                   -61.7526
# 1                    59.6249                   -67.6935
# 2                    49.8397                   -78.3427
# 3                    29.1813                   -73.8966
# 4                     0.7973                   -68.6125
#
#    L3_O3_solar_zenith_angle  L3_CO_CO_column_number_density  \
# 0                   22.3637                          0.0211
# 1                   28.6148                          0.0220
# 2                   34.2970                          0.0207
# 3                   30.5454                          0.0212
# 4                   26.8997                          0.0378
#
#    L3_CO_H2O_column_number_density  L3_CO_cloud_height  L3_CO_sensor_altitude  \
# 0                         883.3325            267.0172            840138.4611
# 1                        1148.9854             61.2167            841116.7631
# 2                        1109.3471            134.7003            841319.8604
# 3                        1061.5708            474.8214            841036.1929
# 4                        1044.2474            926.9263            840710.3422
#
#    L3_CO_sensor_azimuth_angle  L3_CO_sensor_zenith_angle  \
# 0                     74.5434                    38.6225
# 1                    -57.0152                    61.4026
# 2                   -103.4945                    49.9246
# 3                   -101.9559                    29.2150
# 4                     15.4996                     1.3891
#
#    L3_CO_solar_azimuth_angle  L3_CO_solar_zenith_angle  \
# 0                   -61.7890                   22.3791
# 1                   -74.4576                   33.0895
# 2                   -78.3551                   34.3089
# 3                   -73.9146                   30.5445
# 4                   -68.6229                   26.9062
#
#    L3_HCHO_HCHO_slant_column_number_density  L3_HCHO_cloud_fraction  \
# 0                               -1.0413e-05                  0.0000
# 1                                1.1445e-04                  0.0594
# 2                                2.6811e-05                  0.0821
# 3                                2.3487e-05                  0.1213
# 4                                3.7250e-05                  0.0379
#
#    L3_HCHO_sensor_azimuth_angle  L3_HCHO_sensor_zenith_angle  \
# 0                       76.5364                      38.5930
# 1                      -14.7080                      59.6249
# 2                     -105.2013                      49.8397
# 3                     -104.3341                      29.1813
# 4                       58.8502                       0.7973
#
#    L3_HCHO_solar_azimuth_angle  L3_HCHO_solar_zenith_angle  \
# 0                     -61.7526                     22.3637
# 1                     -67.6935                     28.6148
# 2                     -78.3427                     34.2970
# 3                     -73.8966                     30.5454
# 4                     -68.6125                     26.8997
#
#    L3_HCHO_tropospheric_HCHO_column_number_density  \
# 0                                       6.3888e-05
# 1                                       1.7099e-04
# 2                                       1.2390e-04
# 3                                       8.0758e-05
# 4                                       1.4022e-04
#
#    L3_HCHO_tropospheric_HCHO_column_number_density_amf  \
# 0                                             0.5668
# 1                                             0.8584
# 2                                             0.9105
# 3                                             1.1326
# 4                                             0.6494
#
#    L3_CLOUD_cloud_base_height  L3_CLOUD_cloud_base_pressure  \
# 0                         NaN                           NaN
# 1                    175.0199                    99354.1630
# 2                    275.9040                    98118.9352
# 3                    383.6924                    97258.4628
# 4                   4314.4831                    59875.0280
#
#    L3_CLOUD_cloud_fraction  L3_CLOUD_cloud_optical_depth  \
# 0                   0.0000                           NaN
# 1                   0.0594                        5.9585
# 2                   0.0822                        5.7558
# 3                   0.1216                        6.2469
# 4                   0.0370                        4.2057
#
#    L3_CLOUD_cloud_top_height  L3_CLOUD_cloud_top_pressure  \
# 0                        NaN                          NaN
# 1                   175.0721                   99353.6724
# 2                   508.9777                   95671.3836
# 3                   495.3804                   96232.4864
# 4                  5314.4832                   52561.5231
#
#    L3_CLOUD_sensor_azimuth_angle  L3_CLOUD_sensor_zenith_angle  \
# 0                        76.5364                       38.5930
# 1                       -14.7080                       59.6249
# 2                      -105.2013                       49.8397
# 3                      -104.3341                       29.1813
# 4                        58.8502                        0.7973
#
#    L3_CLOUD_solar_azimuth_angle  L3_CLOUD_solar_zenith_angle  \
# 0                      -61.7526                      22.3637
# 1                      -67.6935                      28.6148
# 2                      -78.3427                      34.2970
# 3                      -73.8966                      30.5454
# 4                      -68.6125                      26.8997
#
#    L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# 0                      NaN                            -1.2313
# 1                   0.3154                            -1.0826
# 2                   0.3075                            -1.0012
# 3                   0.2796                            -0.7770
# 4                   0.2382                             0.3663
#
#    L3_AER_AI_sensor_altitude  L3_AER_AI_sensor_azimuth_angle  \
# 0                840209.8746                         76.5375
# 1                840772.9420                        -14.7080
# 2                841410.7135                       -105.2013
# 3                841103.2424                       -104.3341
# 4                840763.0555                         58.8502
#
#    L3_AER_AI_sensor_zenith_angle  L3_AER_AI_solar_azimuth_angle  \
# 0                        38.6343                       -61.7367
# 1                        59.6249                       -67.6935
# 2                        49.8397                       -78.3427
# 3                        29.1810                       -73.8966
# 4                         0.7973                       -68.6125
#
#    L3_AER_AI_solar_zenith_angle  L3_SO2_SO2_column_number_density  \
# 0                       22.3582                           -0.0001
# 1                       28.6148                            0.0002
# 2                       34.2970                            0.0002
# 3                       30.5454                            0.0002
# 4                       26.8997                            0.0004
#
#    L3_SO2_SO2_column_number_density_amf  \
# 0                                0.3125
# 1                                0.4340
# 2                                0.3569
# 3                                0.5845
# 4                                0.4080
#
#    L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 0                             -4.0466e-05                         -1.8615
# 1                              5.0211e-05                         -1.4526
# 2                              5.2949e-05                         -1.5730
# 3                              1.0971e-04                         -1.2393
# 4                              1.5891e-04                          0.2025
#
#    L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# 0                 0.0000                      76.5364
# 1                 0.0594                     -14.7080
# 2                 0.0821                    -105.2013
# 3                 0.1213                    -104.3341
# 4                 0.0379                      58.8502
#
#    L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# 0                     38.5930                    -61.7526
# 1                     59.6249                    -67.6935
# 2                     49.8397                    -78.3427
# 3                     29.1813                    -73.8966
# 4                      0.7973                    -68.6125
#
#    L3_SO2_solar_zenith_angle  L3_CH4_CH4_column_volume_mixing_ratio_dry_air  \
# 0                    22.3637                                      1793.7936
# 1                    28.6148                                      1789.9604
# 2                    34.2970                                            NaN
# 3                    30.5454                                            NaN
# 4                    26.8997                                            NaN
#
#    L3_CH4_aerosol_height  L3_CH4_aerosol_optical_depth  \
# 0              3227.8555                        0.0106
# 1              3384.2266                        0.0151
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#    L3_CH4_sensor_azimuth_angle  L3_CH4_sensor_zenith_angle  \
# 0                       74.481                     37.5015
# 1                       75.630                     55.6575
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    L3_CH4_solar_azimuth_angle  L3_CH4_solar_zenith_angle
# 0                    -62.1426                    22.5451
# 1                    -53.8681                    19.2937
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN

# %%
test.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                               11.6000                               30.2
# 1                               18.3000                               42.9
# 2                               17.6000                               41.3
# 3                               15.0119                               53.1
# 4                                9.7000                               71.6
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                             0.0041                      14.6568
# 1                             0.0059                      15.0265
# 2                             0.0059                      15.5110
# 3                             0.0071                      14.4419
# 4                             0.0081                      11.8963
#
#    u_component_of_wind_10m_above_ground  v_component_of_wind_10m_above_ground  \
# 0                                3.9564                                0.7126
# 1                                4.2304                                0.6619
# 2                                5.2457                                1.6406
# 3                                5.4540                               -0.1905
# 4                                3.5118                               -0.2794
#
#    L3_NO2_NO2_column_number_density  L3_NO2_NO2_slant_column_number_density  \
# 0                        5.3382e-05                                  0.0001
# 1                        5.0448e-05                                  0.0001
# 2                        5.0354e-05                                  0.0001
# 3                        5.4992e-05                                  0.0002
# 4                        5.5080e-05                                  0.0001
#
#    L3_NO2_absorbing_aerosol_index  L3_NO2_cloud_fraction  \
# 0                          0.4662                 0.0108
# 1                         -0.2137                 0.0283
# 2                         -0.2543                 0.0104
# 3                         -0.2685                 0.0888
# 4                          0.4607                 0.0412
#
#    L3_NO2_sensor_altitude  L3_NO2_sensor_azimuth_angle  \
# 0             835670.4927                      68.0994
# 1             835281.8828                      75.9368
# 2             834839.0508                      75.5524
# 3             836269.8339                    -102.2851
# 4             836043.1110                    -102.1340
#
#    L3_NO2_sensor_zenith_angle  L3_NO2_solar_azimuth_angle  \
# 0                      1.4457                    -95.9850
# 1                     34.6389                    -95.0180
# 2                     55.8723                    -94.0154
# 3                     59.1749                    -97.2480
# 4                     40.9259                    -96.0572
#
#    L3_NO2_solar_zenith_angle  L3_NO2_stratospheric_NO2_column_number_density  \
# 0                    22.9420                                      4.5906e-05
# 1                    18.5395                                      4.5071e-05
# 2                    14.1408                                      4.4056e-05
# 3                    32.7307                                      4.2922e-05
# 4                    28.3205                                      4.6997e-05
#
#    L3_NO2_tropopause_pressure  L3_NO2_tropospheric_NO2_column_number_density  \
# 0                   6156.0742                                     7.4754e-06
# 1                   7311.8691                                     5.3004e-06
# 2                   6156.0742                                     6.2976e-06
# 3                   6156.0742                                     1.2069e-05
# 4                   6156.0742                                     8.0856e-06
#
#    L3_O3_O3_column_number_density  L3_O3_O3_effective_temperature  \
# 0                          0.1133                        227.4675
# 1                          0.1104                        227.7887
# 2                          0.1125                        229.2356
# 3                          0.1133                        228.3837
# 4                          0.1146                        229.4902
#
#    L3_O3_cloud_fraction  L3_O3_sensor_azimuth_angle  \
# 0                0.0321                     68.0994
# 1                0.0448                     75.9368
# 2                0.0071                     75.5524
# 3                0.0621                   -102.2851
# 4                0.0428                   -102.1340
#
#    L3_O3_sensor_zenith_angle  L3_O3_solar_azimuth_angle  \
# 0                     1.4457                   -95.9850
# 1                    34.6392                   -95.0176
# 2                    55.8723                   -94.0154
# 3                    59.1742                   -97.2476
# 4                    40.9259                   -96.0573
#
#    L3_O3_solar_zenith_angle  L3_CO_CO_column_number_density  \
# 0                   22.9420                          0.0180
# 1                   18.5395                          0.0196
# 2                   14.1408                          0.0187
# 3                   32.7306                          0.0183
# 4                   28.3205                          0.0187
#
#    L3_CO_H2O_column_number_density  L3_CO_cloud_height  L3_CO_sensor_altitude  \
# 0                         841.1429            155.9830            835625.7853
# 1                        1187.5703            922.3858            835225.2783
# 2                         944.3414           1281.8921            834751.9873
# 3                         873.8504            895.1440            836168.5697
# 4                         666.8091              1.0000            835978.2378
#
#    L3_CO_sensor_azimuth_angle  L3_CO_sensor_zenith_angle  \
# 0                     32.7097                     1.8981
# 1                     73.8081                    34.7209
# 2                     73.8617                    56.0198
# 3                   -100.6521                    59.2465
# 4                   -100.2523                    41.0040
#
#    L3_CO_solar_azimuth_angle  L3_CO_solar_zenith_angle  \
# 0                   -95.9870                   22.9501
# 1                   -95.0171                   18.5486
# 2                   -94.0014                   14.1440
# 3                   -97.2494                   32.7413
# 4                   -96.0599                   28.3325
#
#    L3_HCHO_HCHO_slant_column_number_density  L3_HCHO_cloud_fraction  \
# 0                                7.3011e-05                  0.0321
# 1                                4.8393e-05                  0.0408
# 2                                6.1130e-06                  0.0071
# 3                               -2.5172e-05                  0.0621
# 4                               -9.0371e-05                  0.0421
#
#    L3_HCHO_sensor_azimuth_angle  L3_HCHO_sensor_zenith_angle  \
# 0                       68.0994                       1.4457
# 1                       75.9368                      34.6418
# 2                       75.5524                      55.8723
# 3                     -102.2851                      59.1742
# 4                     -102.1339                      40.9258
#
#    L3_HCHO_solar_azimuth_angle  L3_HCHO_solar_zenith_angle  \
# 0                     -95.9850                     22.9420
# 1                     -95.0149                     18.5391
# 2                     -94.0154                     14.1408
# 3                     -97.2476                     32.7306
# 4                     -96.0576                     28.3205
#
#    L3_HCHO_tropospheric_HCHO_column_number_density  \
# 0                                       8.8257e-05
# 1                                       7.4462e-05
# 2                                       4.2094e-05
# 3                                       1.2664e-05
# 4                                      -2.7373e-05
#
#    L3_HCHO_tropospheric_HCHO_column_number_density_amf  \
# 0                                             1.4940
# 1                                             1.5345
# 2                                             1.6805
# 3                                             1.6531
# 4                                             1.4265
#
#    L3_CLOUD_cloud_base_height  L3_CLOUD_cloud_base_pressure  \
# 0                   2592.6342                    74028.4292
# 1                   7334.6011                    48466.6533
# 2                   5188.5241                    61477.2919
# 3                   2601.2824                    74707.1284
# 4                   2557.1967                    74589.2767
#
#    L3_CLOUD_cloud_fraction  L3_CLOUD_cloud_optical_depth  \
# 0                   0.0323                        6.3175
# 1                   0.0462                        8.3084
# 2                   0.0078                        6.4155
# 3                   0.0614                        6.4465
# 4                   0.0422                        6.8740
#
#    L3_CLOUD_cloud_top_height  L3_CLOUD_cloud_top_pressure  \
# 0                  2593.1374                   74023.9307
# 1                  7902.9375                   46345.6130
# 2                  5797.7422                   57757.8422
# 3                  2629.1130                   74535.2862
# 4                  2571.2933                   74483.6803
#
#    L3_CLOUD_sensor_azimuth_angle  L3_CLOUD_sensor_zenith_angle  \
# 0                        68.0994                        1.4457
# 1                        75.9368                       34.6392
# 2                        75.5524                       55.8723
# 3                      -102.2851                       59.1742
# 4                      -102.1340                       40.9259
#
#    L3_CLOUD_solar_azimuth_angle  L3_CLOUD_solar_zenith_angle  \
# 0                      -95.9850                      22.9420
# 1                      -95.0176                      18.5395
# 2                      -94.0154                      14.1408
# 3                      -97.2476                      32.7306
# 4                      -96.0573                      28.3205
#
#    L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# 0                   0.2991                             0.4662
# 1                   0.2904                            -0.2137
# 2                   0.2793                            -0.2543
# 3                   0.3591                            -0.2685
# 4                   0.3315                             0.4607
#
#    L3_AER_AI_sensor_altitude  L3_AER_AI_sensor_azimuth_angle  \
# 0                835670.4927                         68.0994
# 1                835281.8828                         75.9368
# 2                834839.0508                         75.5524
# 3                836269.8339                       -102.2851
# 4                836043.1110                       -102.1340
#
#    L3_AER_AI_sensor_zenith_angle  L3_AER_AI_solar_azimuth_angle  \
# 0                         1.4457                       -95.9850
# 1                        34.6389                       -95.0180
# 2                        55.8723                       -94.0154
# 3                        59.1749                       -97.2480
# 4                        40.9259                       -96.0572
#
#    L3_AER_AI_solar_zenith_angle  L3_SO2_SO2_column_number_density  \
# 0                       22.9420                        2.2071e-04
# 1                       18.5395                        3.3869e-05
# 2                       14.1408                        1.8393e-04
# 3                       32.7307                        2.0087e-04
# 4                       28.3205                        9.3390e-05
#
#    L3_SO2_SO2_column_number_density_amf  \
# 0                                0.7844
# 1                                0.6790
# 2                                0.6678
# 3                                0.6968
# 4                                0.6773
#
#    L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 0                              1.8359e-04                         -0.1405
# 1                              1.3535e-05                         -0.8427
# 2                              1.2192e-04                         -0.7168
# 3                              1.3288e-04                         -0.7301
# 4                              6.5262e-05                         -0.1084
#
#    L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# 0                 0.0321                      68.0994
# 1                 0.0408                      75.9368
# 2                 0.0071                      75.5524
# 3                 0.0621                    -102.2851
# 4                 0.0428                    -102.1340
#
#    L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# 0                      1.4457                    -95.9850
# 1                     34.6418                    -95.0149
# 2                     55.8723                    -94.0154
# 3                     59.1742                    -97.2476
# 4                     40.9259                    -96.0573
#
#    L3_SO2_solar_zenith_angle  L3_CH4_CH4_column_volume_mixing_ratio_dry_air  \
# 0                    22.9420                                            NaN
# 1                    18.5391                                            NaN
# 2                    14.1408                                            NaN
# 3                    32.7306                                            NaN
# 4                    28.3205                                      1831.2616
#
#    L3_CH4_aerosol_height  L3_CH4_aerosol_optical_depth  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4              3229.1187                        0.0311
#
#    L3_CH4_sensor_azimuth_angle  L3_CH4_sensor_zenith_angle  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                    -100.2783                     41.8471
#
#    L3_CH4_solar_azimuth_angle  L3_CH4_solar_zenith_angle
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                    -95.9107                    28.4988

# %%
sample_sub.head()
# Out:
#         Place_ID X Date  target
# 0  0OS9LVX X 2020-01-02       0
# 1  0OS9LVX X 2020-01-03       0
# 2  0OS9LVX X 2020-01-04       0
# 3  0OS9LVX X 2020-01-05       0
# 4  0OS9LVX X 2020-01-06       0

# %%
train.shape, test.shape
# Out:
# ((30557, 85), (16136, 79))

# %%
train.isna().sum().sum(), test.isna().sum().sum()
# Out:
# (388262, 215137)

# %%
TARGET = 'target'
TEST_INDEX = test['Place_ID X Date']

# %% [markdown]
# # Feature exploration

# %%
def plot_cont(feature):
    """Plot side-by-side kdeplots for train and test
    data distribution of continuous feature.
    """
    fig, ax = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(20, 4))
    plt.suptitle(f'Feature: {feature}', fontweight='bold')
    sns.kdeplot(x=feature, data=train, ax=ax[0], cut=0)
    ax[0].set_title('Train data')
    sns.kdeplot(x=feature, data=test, ax=ax[1], cut=0)
    ax[1].set_title('Test data')
    fig.tight_layout()
    plt.show()

def plot_cont_vs_target(feature):
    """Plot scatterplot with continuous feature on
    x-axis and Target on y-axis.
    """
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))
    plt.suptitle(f'{feature} vs. {TARGET}', fontweight='bold')
    sns.scatterplot(x=feature, y=TARGET, data=train, ax=ax)
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ### Date

# %%
train['Date'] = pd.to_datetime(train['Date'])
test['Date'] = pd.to_datetime(test['Date'])

# %%
train['Date'].min(), train['Date'].max()
# Out:
# (Timestamp('2020-01-02 00:00:00'), Timestamp('2020-04-04 00:00:00'))

# %%
test['Date'].min(), test['Date'].max()
# Out:
# (Timestamp('2020-01-02 00:00:00'), Timestamp('2020-04-04 00:00:00'))

# %% [markdown]
# Train and test data cover the same time duration.

# %%
train['month'] = train['Date'].dt.month
test['month'] = test['Date'].dt.month

# %%
train['day'] = train['Date'].dt.day
test['day'] = test['Date'].dt.day

# %%
train['day_of_week'] = train['Date'].dt.day_of_week
test['day_of_week'] = test['Date'].dt.day_of_week

# %% [markdown]
# ### Place_ID

# %%
train['Place_ID'].nunique(), test['Place_ID'].nunique()
# Out:
# (340, 179)

# %%
set(train['Place_ID'].unique()).intersection(set(test['Place_ID'].unique()))
# Out:
# set()

# %% [markdown]
# * No common Place_IDs.
# * Train and test data contain data from same time period but different places.

# %%
train['Place_ID'].sample(5, random_state=SEED)
# Out:
# 21369    OEN2305
# 686      0MGEY68
# 2279     1WD100Y
# 5885     5YBO7PQ
# 12440    DG199GT
# Name: Place_ID, dtype: category
# Categories (340, object): ['010Q650', '05EC30X', '0DPWHX8', '0GBXTHY', ..., 'YLZOBFW', 'YPXSK14',
#                            'YSIXKFZ', 'YWSFY6Q']

# %%
[f for f in train['Place_ID'].unique() if f.startswith('D')]
# Out:
# ['D1G84CB', 'D1OBVR6', 'D41QK7I', 'D7K9KM7', 'DALZSBE', 'DC6LSFX', 'DCBEVTO', 'DDMR0JF', 'DDN3QS2', 'DG199GT', 'DHRND6U', 'DHVQZD8', 'DIHJFZ0', 'DPQKOA5', 'DRFD4D1', 'DSG5LHH', 'DSGAHLQ', 'DXU9CSJ', 'DXV3CMF']

# %%
[f for f in test['Place_ID'].unique() if f.startswith('D')]
# Out:
# ['D204H3S', 'D225A7N', 'DES3SOP', 'DF5ZLRW', 'DK41FJZ', 'DQV2FW5', 'DRBCSEX', 'DRUU4MV']

# %%
[f for f in train['Place_ID'].unique() if f.startswith('1')]
# Out:
# ['11WPGRD', '168B2T2', '1GZGJPN', '1LC5FAK', '1PRBF5P', '1RYCZPT', '1SC5AWD', '1SKLTGJ', '1TE1HKJ', '1UEYEJQ', '1VN0K1S', '1WD100Y', '1X421B8', '1Y0S7TZ', '1YXF6T3', '1Z0FIHB', '1ZBVIMD']

# %%
[f for f in test['Place_ID'].unique() if f.startswith('1')]
# Out:
# ['15WCXN1', '19090SM', '1BD5TVT', '1JJE0UY', '1PILPB3', '1WV2OIN']

# %% [markdown]
# No discernible pattern for forming groups.

# %%
train['Place_ID'].value_counts(normalize=True)[:5]
# Out:
# 010Q650    0.0031
# JSXAVKO    0.0031
# I5RGE5G    0.0031
# I6718VY    0.0031
# I6VIR8R    0.0031
# Name: Place_ID, dtype: float64

# %%
train['Place_ID'].value_counts(normalize=True)[-5:]
# Out:
# LKE9VQB    1.3418e-03
# S91MBTB    9.4905e-04
# 6KAHP8X    3.9271e-04
# MJSB8K5    2.2908e-04
# 5IUK9TG    9.8177e-05
# Name: Place_ID, dtype: float64

# %% [markdown]
# Some places are less represented in the data.

# %% [markdown]
# ### precipitable_water_entire_atmosphere

# %%
plot_cont('precipitable_water_entire_atmosphere')

# %%
plot_cont_vs_target('precipitable_water_entire_atmosphere')

# %% [markdown]
# ### relative_humidity_2m_above_ground

# %%
plot_cont('relative_humidity_2m_above_ground')

# %%
plot_cont_vs_target('relative_humidity_2m_above_ground')

# %% [markdown]
# ### specific_humidity_2m_above_ground

# %%
plot_cont('specific_humidity_2m_above_ground')

# %%
plot_cont_vs_target('specific_humidity_2m_above_ground')

# %%
train['specific_humidity_2m_above_ground'].corr(train['relative_humidity_2m_above_ground'])
# Out:
# 0.21950909499881505

# %% [markdown]
# ### temperature_2m_above_ground

# %%
plot_cont('temperature_2m_above_ground')

# %%
plot_cont_vs_target('temperature_2m_above_ground')

# %% [markdown]
# ### u_component_of_wind_10m_above_ground

# %%
plot_cont('u_component_of_wind_10m_above_ground')

# %%
plot_cont_vs_target('u_component_of_wind_10m_above_ground')

# %% [markdown]
# ### v_component_of_wind_10m_above_ground

# %%
plot_cont('v_component_of_wind_10m_above_ground')

# %%
plot_cont_vs_target('v_component_of_wind_10m_above_ground')

# %% [markdown]
# # Baseline

# %%
reduced_features = [
                    'month', 'day', 'day_of_week', 
                    'precipitable_water_entire_atmosphere',
                    'relative_humidity_2m_above_ground', 
                    'specific_humidity_2m_above_ground', 
                    'temperature_2m_above_ground', 
                    'u_component_of_wind_10m_above_ground', 
                    'v_component_of_wind_10m_above_ground'
                   ]

all_features = [f for f in test.columns if f not in ('Place_ID X Date', 'Date', 'Place_ID')]

# %%
#imputation for baseline
train_imp = train.fillna(-999)
test_imp = test.fillna(-999)

# %%
train['Place_ID'] = train['Place_ID'].astype('category') #for GroupKFold
test['Place_ID'] = test['Place_ID'].astype('category')

# %%
def evaluate_model(model, features, verbose=True):
    oof_preds = {}  #out-of-fold predictions on train set
    test_preds = {} #predictions on test set for each fold
    scores_rmse = [] #RMSE scores on validation set

    X = train_imp[features]
    y = train_imp[TARGET]
    X_test = test_imp[features]

    cv = GroupKFold(n_splits=10)
    groups = np.array(train['Place_ID'])
    for fold, (train_idx, val_idx) in enumerate(cv.split(X, y, groups)):
        X_train, y_train = X.loc[train_idx], y.iloc[train_idx]
        X_val, y_val = X.loc[val_idx], y.iloc[val_idx]
        
        model.fit(X_train, y_train)
        val_preds = model.predict(X_val)
        oof_preds.update(dict(zip(val_idx, val_preds)))
        test_preds[f'fold{fold}'] = model.predict(X_test)

        score = mean_squared_error(y_val, val_preds, squared=False)
        scores_rmse.append(score)
        if verbose:
            print(f'Fold #{fold}: RMSE = {score:.5f}')
        
        _ = gc.collect()

    print(f'\nAvg RMSE = {np.mean(scores_rmse):.5f} +/- {np.std(scores_rmse):.5f}')
    
    oof_preds = pd.Series(oof_preds).sort_index()
    print(f'OOF RMSE = {mean_squared_error(y, oof_preds, squared=False):.5f}')
    test_preds = pd.DataFrame.from_dict(test_preds)
    return oof_preds, test_preds

# %%
# %%time
model_1 = RandomForestRegressor()
oof_preds_1, test_preds_1 = evaluate_model(model_1, reduced_features)
# Out:
# Fold #0: RMSE = 44.61106
# Fold #1: RMSE = 44.43199
# Fold #2: RMSE = 35.76417
# Fold #3: RMSE = 40.79867
# Fold #4: RMSE = 52.59247
# Fold #5: RMSE = 46.89622
# Fold #6: RMSE = 36.48916
# Fold #7: RMSE = 40.39378
# Fold #8: RMSE = 37.35589
# Fold #9: RMSE = 32.95684
#
# Avg RMSE = 41.22902 +/- 5.65320
# OOF RMSE = 41.61704
# CPU times: user 3min 49s, sys: 345 ms, total: 3min 49s
# Wall time: 3min 49s

# %%
# %%time
model_2 = RandomForestRegressor()
oof_preds_2, test_preds_2 = evaluate_model(model_2, all_features)
# Out:
# Fold #0: RMSE = 36.02419
# Fold #1: RMSE = 31.52534
# Fold #2: RMSE = 28.87974
# Fold #3: RMSE = 37.46206
# Fold #4: RMSE = 43.83509
# Fold #5: RMSE = 34.48875
# Fold #6: RMSE = 31.89331
# Fold #7: RMSE = 29.62409
# Fold #8: RMSE = 30.02625
# Fold #9: RMSE = 26.60885
#
# Avg RMSE = 33.03677 +/- 4.79709
# OOF RMSE = 33.38953
# CPU times: user 31min 55s, sys: 2 s, total: 31min 57s
# Wall time: 31min 50s

# %%
def create_submission_files(
        predictions_df,
        model_number, 
        feature_set,  
        path=SUBMISSION_PATH):
    
    file_path = f'{path}/m_{model_number}'
    if not os.path.isdir(file_path):
        os.mkdir(file_path)

    for col in (predictions_df.columns):
        sub = pd.DataFrame({'Place_ID X Date': TEST_INDEX,'target': predictions_df[col]})
        sub.to_csv(f'{file_path}/{feature_set}_{col}.csv', index=False)

    sub = pd.DataFrame({'Place_ID X Date': TEST_INDEX,'target': predictions_df.mean(axis=1)})
    sub.to_csv(f'{file_path}/{feature_set}_mean.csv', index=False)

# %%
# create_submission_files(test_preds_1, model_number='01', feature_set='reduced')

# %%
# create_submission_files(test_preds_2, model_number='02', feature_set='all')
