# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install --upgrade xgboost

# %%
import os
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('precision', 4)
np.set_printoptions(precision=4)

from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

SEED = 23
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
data_url = 'https://raw.githubusercontent.com/stiwari-ds/data-science-competitions/main/dphi/juniper_networks_global_challenge/data/'

train = pd.read_csv(data_url + 'raw/train.csv')
test = pd.read_csv(data_url + 'raw/test.csv')

# %% [markdown]
# # Data Overview

# %%
train.head()
# Out:
#    Unnamed: 0                        observation_id observation_timestamp  \
# 0           0  704d2a80-d52e-11ec-90ff-c7e6292284b3   2022-05-16 15:39:57
# 1           1  1cacc1d0-e6ac-11ec-b65d-156af70ce36b   2022-06-07 21:52:23
# 2           2  6dc2b330-d37a-11ec-884e-dfe9ea4a7bd5   2022-05-14 11:38:52
# 3           3  163ee0a0-0cca-11ed-a73c-8904b24187cc   2022-07-26 10:02:41
# 4           4  5e3c5df0-d5ee-11ec-a5f2-3b6f99e95850   2022-05-17 14:33:50
#
#    hour_of_day  register__sales_dollar_amt_this_hour  \
# 0           15                                347.29
# 1           21                                361.59
# 2           11                                850.73
# 3           10                               1175.69
# 4           14                               3204.53
#
#   register__payment_types_accepted  register__peak_sales_dollar_amt_per_hour  \
# 0                      Cash+Credit                                   -0.7383
# 1                      Cash+Credit                                    0.6483
# 2                      Cash+Credit                                   -0.4950
# 3                      Cash+Credit                                   -0.5594
# 4                      Cash+Credit                                    0.5693
#
#    register__sales_dollar_amt_last_hour  register__sales_quantity_last_hour  \
# 0                               -0.1270                             -0.1993
# 1                               -0.0362                             -0.0777
# 2                               -0.1268                             -0.1974
# 3                               -0.1270                             -0.1991
# 4                               -0.1221                             -0.1632
#
#    register__sales_quantity_rescanned_frac  \
# 0                                  -0.8299
# 1                                  -0.7395
# 2                                   1.3139
# 3                                  -0.8299
# 4                                  -0.7071
#
#    register__sales_payments_declined_frac  \
# 0                                 -0.1247
# 1                                 -0.1135
# 2                                  0.1075
# 3                                 -0.1247
# 4                                 -0.1247
#
#    register__peak_returns_dollar_amt_per_hour  \
# 0                                     -0.5721
# 1                                     -0.5251
# 2                                     -0.5251
# 3                                     -0.5251
# 4                                      0.7604
#
#    register__returns_dollar_amt_last_hour  \
# 0                                 -0.2582
# 1                                 -0.2157
# 2                                 -0.2579
# 3                                 -0.2582
# 4                                 -0.2565
#
#    register__returns_quantity_last_hour  \
# 0                               -0.2621
# 1                               -0.1252
# 2                               -0.2542
# 3                               -0.2616
# 4                               -0.2505
#
#    register__returns_quantity_rescanned_frac  cashier__title_level  \
# 0                                    -0.5337               -2.6036
# 1                                    -0.2853               -0.3520
# 2                                    -0.1125               -0.3520
# 3                                    -0.2958               -0.3520
# 4                                    -0.0756                1.8996
#
#    cashier__n_years_experience  cashier__hours_into_shift  \
# 0                      -2.5371                     1.0551
# 1                       1.0463                    -0.2628
# 2                       1.0463                    -0.6884
# 3                       1.0463                    -0.2024
# 4                      -0.7454                    -0.3341
#
#    cashier__item_scan_rate_per_min  cashier__item_manual_entry_rate_per_min  \
# 0                           0.9156                                   0.6773
# 1                           0.9156                                   0.5731
# 2                          -0.0118                                   0.0520
# 3                          -0.2178                                  -0.0522
# 4                          -0.3209                                  -0.4691
#
#   store__type_code  store__miles_to_nearest_location  \
# 0                A                            0.4564
# 1                A                            0.7155
# 2                A                           -2.1342
# 3                A                           -2.1342
# 4                D                            0.1973
#
#    store__target_sales_quantity_per_hour  store__mean_customer_to_staff_ratio  \
# 0                                -0.0092                               0.8432
# 1                                -0.0114                               1.1964
# 2                                 0.0708                              -0.2166
# 3                                 0.1041                              -0.5699
# 4                                 0.1041                               0.4899
#
#    store__mean_service_time_per_customer  store__n_employees_total  \
# 0                                -0.6449                    0.0580
# 1                                 0.6649                   -0.2960
# 2                                -1.1229                    0.9549
# 3                                -1.1216                    0.9549
# 4                                 0.4485                   -2.9041
#
#    store__n_managers  store__n_baggers  store__n_open_registers  \
# 0            -0.3657            0.1657                   0.4640
# 1             1.9243            0.1657                  -0.5796
# 2            -0.3657           -0.6371                  -0.7536
# 3            -0.3657           -0.6371                  -0.7536
# 4            -0.9381            0.1657                  -0.2318
#
#    store__is_sufficiently_staffed  store__occupancy_main_floor  \
# 0                         -0.3909                      -0.6325
# 1                         -0.3909                      -0.4198
# 2                          2.5582                      -0.6413
# 3                          2.5582                      -0.6456
# 4                         -0.3909                      -0.6240
#
#    store__occupancy_grocery  store__occupancy_checkout_areas  \
# 0                   -0.7099                          -0.4386
# 1                    0.3457                          -0.4386
# 2                   -0.7512                           3.4854
# 3                   -0.7712                           1.8422
# 4                   -0.5775                          -0.4386
#
#    store__occupancy_food_court  store__occupancy_backrooms  \
# 0                      -0.5688                      0.0721
# 1                       0.4618                     -0.1019
# 2                      -0.2706                      0.4125
# 3                       0.6375                      0.5038
# 4                      -0.5855                     -0.1770
#
#    store__occupancy_indoors  store__occupancy_outdoors  \
# 0                   -0.8838                    -0.5614
# 1                   -0.1205                    -0.1695
# 2                    0.0888                     2.6556
# 3                   -0.2011                     1.7377
# 4                   -0.8225                    -0.5903
#
#    store__outdoor_temperature  store__parking_lot_utilization  \
# 0                      0.6376                          0.1789
# 1                      0.6376                         -1.1085
# 2                     -0.2052                          1.1999
# 3                      1.4289                          1.2568
# 4                     -0.0431                         -0.9823
#
#    store__shelf_freespace_frac  store__hrs_since_last_delivery  \
# 0                       0.3840                         -0.3093
# 1                      -1.4293                         -1.1059
# 2                       0.6431                         -0.8367
# 3                       0.2545                          0.0550
# 4                      -1.2998                          2.7499
#
#    store__sales_dollar_amt_last_hour  store__sales_quantity_last_hour  \
# 0                            -0.5487                          -0.5871
# 1                            -0.4608                          -0.3796
# 2                            -0.5488                          -0.5921
# 3                            -0.5492                          -0.5956
# 4                            -0.5457                          -0.5774
#
#    store__sales_quantity_rescanned_frac  store__gift_sales_quantity_last_hour  \
# 0                               -0.0124                               -0.4095
# 1                               -0.0124                               -0.4119
# 2                               -0.0124                                3.5004
# 3                               -0.0124                                2.1668
# 4                               -0.0124                               -0.4119
#
#    store__returns_dollar_amt_last_hour  store__returns_quantity_last_hour  \
# 0                              -0.4308                            -0.5274
# 1                              -0.1632                            -0.2623
# 2                              -0.4335                            -0.5391
# 3                              -0.4343                            -0.5438
# 4                              -0.4189                            -0.4578
#
#    store__returns_quantity_rescanned_frac  \
# 0                                 -0.3301
# 1                                 -0.3301
# 2                                 -0.3301
# 3                                 -0.3301
# 4                                 -0.3035
#
#    store__gift_returns_quantity_last_hour  region__n_stores  \
# 0                                 -0.2847           -0.7599
# 1                                 -0.2797           -0.7599
# 2                                  0.1894           -0.3367
# 3                                  0.1188           -0.3838
# 4                                 -0.2948           -0.6188
#
#    region__n_open_registers  region__mean_service_time_per_customer  \
# 0                   -0.5978                                 -0.9255
# 1                   -0.7147                                  0.7815
# 2                   -0.6782                                 -1.2559
# 3                   -0.6709                                 -1.2280
# 4                   -0.6562                                  0.2442
#
#    region__stdev_service_time_per_customer  \
# 0                                  -0.3891
# 1                                   0.0663
# 2                                  -0.4826
# 3                                  -0.4809
# 4                                  -0.3021
#
#    region__sales_dollar_amt_last_hour  region__returns_dollar_amt_last_hour  \
# 0                             -0.6920                               -0.4605
# 1                             -0.6531                               -0.4434
# 2                             -0.6120                               -0.1786
# 3                             -0.5472                                0.1246
# 4                             -0.3838                                0.1996
#
#    region__nighttime_open_registers  \
# 0                           -0.5180
# 1                           -0.6498
# 2                           -0.6040
# 3                           -0.5925
# 4                           -0.5696
#
#    region__nighttime_service_time_per_customer  \
# 0                                      -1.0062
# 1                                       0.9031
# 2                                      -1.4229
# 3                                      -1.4097
# 4                                       1.1231
#
#    region__nighttime_sales_amt_per_hour  \
# 0                               -0.6462
# 1                               -0.6493
# 2                               -0.6456
# 3                               -0.6478
# 4                               -0.6475
#
#    region__nighttime_returns_amt_per_hour  \
# 0                                 -0.6030
# 1                                 -0.6106
# 2                                 -0.6037
# 3                                 -0.6079
# 4                                 -0.6032
#
#    region__peak_sales_dollar_amt_per_hour  \
# 0                                 -0.4773
# 1                                  0.4998
# 2                                  1.9337
# 3                                  0.1288
# 4                                  1.0050
#
#    region__peak_sales_dollar_amt_per_hour_v2  \
# 0                                     0.1748
# 1                                    -0.9816
# 2                                    -0.9093
# 3                                    -0.9093
# 4                                     0.1748
#
#    region__peak_returns_dollar_amt_per_hour  \
# 0                                   -1.7951
# 1                                    0.8939
# 2                                    2.4046
# 3                                   -0.4983
# 4                                    1.5660
#
#    region__peak_returns_dollar_amt_per_hour_v2
# 0                                      -0.8284
# 1                                      -0.8614
# 2                                      -0.7567
# 3                                      -0.7567
# 4                                       0.2356

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18512 entries, 0 to 18511
# Data columns (total 63 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   18512 non-null  int64
#  1   observation_id                               18512 non-null  object
#  2   observation_timestamp                        18512 non-null  object
#  3   hour_of_day                                  18512 non-null  int64
#  4   register__sales_dollar_amt_this_hour         18512 non-null  float64
#  5   register__payment_types_accepted             18512 non-null  object
#  6   register__peak_sales_dollar_amt_per_hour     18512 non-null  float64
#  7   register__sales_dollar_amt_last_hour         18512 non-null  float64
#  8   register__sales_quantity_last_hour           18512 non-null  float64
#  9   register__sales_quantity_rescanned_frac      18512 non-null  float64
#  10  register__sales_payments_declined_frac       18512 non-null  float64
#  11  register__peak_returns_dollar_amt_per_hour   18512 non-null  float64
#  12  register__returns_dollar_amt_last_hour       18512 non-null  float64
#  13  register__returns_quantity_last_hour         18512 non-null  float64
#  14  register__returns_quantity_rescanned_frac    18512 non-null  float64
#  15  cashier__title_level                         18512 non-null  float64
#  16  cashier__n_years_experience                  18512 non-null  float64
#  17  cashier__hours_into_shift                    18512 non-null  float64
#  18  cashier__item_scan_rate_per_min              18512 non-null  float64
#  19  cashier__item_manual_entry_rate_per_min      18512 non-null  float64
#  20  store__type_code                             18512 non-null  object
#  21  store__miles_to_nearest_location             18512 non-null  float64
#  22  store__target_sales_quantity_per_hour        18512 non-null  float64
#  23  store__mean_customer_to_staff_ratio          18512 non-null  float64
#  24  store__mean_service_time_per_customer        18512 non-null  float64
#  25  store__n_employees_total                     18512 non-null  float64
#  26  store__n_managers                            18512 non-null  float64
#  27  store__n_baggers                             18512 non-null  float64
#  28  store__n_open_registers                      18512 non-null  float64
#  29  store__is_sufficiently_staffed               18512 non-null  float64
#  30  store__occupancy_main_floor                  18512 non-null  float64
#  31  store__occupancy_grocery                     18512 non-null  float64
#  32  store__occupancy_checkout_areas              18512 non-null  float64
#  33  store__occupancy_food_court                  18512 non-null  float64
#  34  store__occupancy_backrooms                   18512 non-null  float64
#  35  store__occupancy_indoors                     18512 non-null  float64
#  36  store__occupancy_outdoors                    18512 non-null  float64
#  37  store__outdoor_temperature                   18512 non-null  float64
#  38  store__parking_lot_utilization               18512 non-null  float64
#  39  store__shelf_freespace_frac                  18512 non-null  float64
#  40  store__hrs_since_last_delivery               18512 non-null  float64
#  41  store__sales_dollar_amt_last_hour            18512 non-null  float64
#  42  store__sales_quantity_last_hour              18512 non-null  float64
#  43  store__sales_quantity_rescanned_frac         18512 non-null  float64
#  44  store__gift_sales_quantity_last_hour         18512 non-null  float64
#  45  store__returns_dollar_amt_last_hour          18512 non-null  float64
#  46  store__returns_quantity_last_hour            18512 non-null  float64
#  47  store__returns_quantity_rescanned_frac       18512 non-null  float64
#  48  store__gift_returns_quantity_last_hour       18512 non-null  float64
#  49  region__n_stores                             18512 non-null  float64
#  50  region__n_open_registers                     18512 non-null  float64
#  51  region__mean_service_time_per_customer       18512 non-null  float64
#  52  region__stdev_service_time_per_customer      18512 non-null  float64
#  53  region__sales_dollar_amt_last_hour           18512 non-null  float64
#  54  region__returns_dollar_amt_last_hour         18512 non-null  float64
#  55  region__nighttime_open_registers             18512 non-null  float64
#  56  region__nighttime_service_time_per_customer  18512 non-null  float64
#  57  region__nighttime_sales_amt_per_hour         18512 non-null  float64
#  58  region__nighttime_returns_amt_per_hour       18512 non-null  float64
#  59  region__peak_sales_dollar_amt_per_hour       18512 non-null  float64
#  60  region__peak_sales_dollar_amt_per_hour_v2    18314 non-null  float64
#  61  region__peak_returns_dollar_amt_per_hour     18512 non-null  float64
#  62  region__peak_returns_dollar_amt_per_hour_v2  16612 non-null  float64
# dtypes: float64(57), int64(2), object(4)
# memory usage: 8.9+ MB

# %%
test.head()
# Out:
#                          observation_id observation_timestamp  hour_of_day  \
# 0  3f483640-bc52-11ec-b736-8544dc068949      15/04/2022 00:23            0
# 1  a88b0bb0-d2ae-11ec-bd0e-f5a7c7895456      13/05/2022 11:20           11
# 2  90611780-d607-11ec-a5d8-675445c92326      17/05/2022 17:34           17
# 3  a98380e0-e2d2-11ec-b28f-7f4d381958ee      03/06/2022 00:18            0
# 4  608b8e60-e4f2-11ec-8115-d3258731976b      05/06/2022 17:10           17
#
#   register__payment_types_accepted  register__peak_sales_dollar_amt_per_hour  \
# 0                      Cash+Credit                                    0.5693
# 1                      Cash+Credit                                    0.3084
# 2                      Cash+Credit                                   -0.6757
# 3                      Cash+Credit                                   -0.1747
# 4                      Cash+Credit                                    0.6483
#
#    register__sales_dollar_amt_last_hour  register__sales_quantity_last_hour  \
# 0                               -0.1253                             -0.1489
# 1                               -0.1270                             -0.1986
# 2                                0.1925                              0.2534
# 3                               -0.1258                             -0.1709
# 4                               -0.0612                             -0.0995
#
#    register__sales_quantity_rescanned_frac  \
# 0                                  -0.8176
# 1                                   1.6562
# 2                                  -0.7517
# 3                                  -0.3576
# 4                                   0.1060
#
#    register__sales_payments_declined_frac  \
# 0                                 -0.1066
# 1                                 -0.1247
# 2                                 -0.1247
# 3                                 -0.1247
# 4                                 -0.1247
#
#    register__peak_returns_dollar_amt_per_hour  \
# 0                                      0.9103
# 1                                     -0.5251
# 2                                     -0.5251
# 3                                     -0.5251
# 4                                     -0.5251
#
#    register__returns_dollar_amt_last_hour  \
# 0                                 -0.1930
# 1                                 -0.2581
# 2                                  0.8384
# 3                                 -0.2304
# 4                                 -0.2169
#
#    register__returns_quantity_last_hour  \
# 0                               -0.2177
# 1                               -0.2601
# 2                                0.7034
# 3                               -0.2174
# 4                               -0.1434
#
#    register__returns_quantity_rescanned_frac  cashier__title_level  \
# 0                                    -0.5078                1.8996
# 1                                    -0.5337               -0.3520
# 2                                    -0.2254               -0.3520
# 3                                    -0.5308               -0.3520
# 4                                    -0.5186               -0.3520
#
#    cashier__n_years_experience  cashier__hours_into_shift  \
# 0                      -0.7454                    -0.7090
# 1                       1.0463                     0.0167
# 2                      -0.7454                    -0.2369
# 3                       1.0463                     0.2179
# 4                       1.0463                    -0.5244
#
#    cashier__item_scan_rate_per_min  cashier__item_manual_entry_rate_per_min  \
# 0                           2.0490                                   1.8238
# 1                           1.1217                                   0.9900
# 2                           0.0913                                   0.3647
# 3                           1.0186                                   0.8858
# 4                           0.9156                                   0.7816
#
#   store__type_code  store__miles_to_nearest_location  \
# 0                C                            0.9745
# 1                C                            0.4564
# 2                A                            0.1973
# 3                C                            0.9745
# 4                C                            0.9745
#
#    store__target_sales_quantity_per_hour  store__mean_customer_to_staff_ratio  \
# 0                                 0.1041                               0.8432
# 1                                -0.1891                               0.4899
# 2                                -0.0158                              -0.9231
# 3                                 0.0508                               0.4899
# 4                                 0.0463                               0.4899
#
#    store__mean_service_time_per_customer  store__n_employees_total  \
# 0                                 0.9297                    1.3797
# 1                                 0.1748                    0.9549
# 2                                -0.1971                   -0.2960
# 3                                 0.3391                    0.9549
# 4                                 0.5910                    0.9549
#
#    store__n_managers  store__n_baggers  store__n_open_registers  \
# 0            -0.9381            0.1657                  -0.5796
# 1             0.2068            0.1657                  -0.7536
# 2            -0.3657           -0.6371                  -0.0578
# 3             0.2068            0.1657                  -0.7536
# 4             0.2068            0.1657                  -0.7536
#
#    store__is_sufficiently_staffed  store__occupancy_main_floor  \
# 0                         -0.3909                      -0.6463
# 1                         -0.3909                      -0.6438
# 2                         -0.3909                       2.2737
# 3                         -0.3909                      -0.5560
# 4                         -0.3909                      -0.4622
#
#    store__occupancy_grocery  store__occupancy_checkout_areas  \
# 0                   -0.8466                           0.9721
# 1                   -0.6615                          -0.4386
# 2                    0.6620                           0.0212
# 3                   -0.4236                          -0.4386
# 4                    0.2266                          -0.3946
#
#    store__occupancy_food_court  store__occupancy_backrooms  \
# 0                       0.0288                     -0.1693
# 1                      -0.8726                     -0.0441
# 2                      -0.5885                     -0.1733
# 3                      -0.5051                     -0.1467
# 4                       0.4046                     -0.1019
#
#    store__occupancy_indoors  store__occupancy_outdoors  \
# 0                   -0.5504                     0.7565
# 1                   -0.9067                    -0.6919
# 2                    1.5244                    -0.2315
# 3                   -0.6975                    -0.5558
# 4                   -0.1996                    -0.1578
#
#    store__outdoor_temperature  store__parking_lot_utilization  \
# 0                     -0.2052                          0.8869
# 1                      0.8842                          0.9393
# 2                     -1.4046                         -1.0434
# 3                      0.2307                          0.9887
# 4                      0.1216                          1.0034
#
#    store__shelf_freespace_frac  store__hrs_since_last_delivery  \
# 0                       0.9021                         -1.0340
# 1                      -0.2636                         -0.4222
# 2                      -0.2636                         -0.0714
# 3                       0.7726                          0.9128
# 4                       0.7726                          1.0884
#
#    store__sales_dollar_amt_last_hour  store__sales_quantity_last_hour  \
# 0                            -0.5493                          -0.5959
# 1                            -0.5492                          -0.5948
# 2                             1.8831                           1.6804
# 3                            -0.4882                          -0.5392
# 4                            -0.4619                          -0.4192
#
#    store__sales_quantity_rescanned_frac  store__gift_sales_quantity_last_hour  \
# 0                               -0.0124                                1.4187
# 1                               -0.0124                               -0.4107
# 2                               -0.0124                                0.0797
# 3                               -0.0124                               -0.4095
# 4                               -0.0124                               -0.3288
#
#    store__returns_dollar_amt_last_hour  store__returns_quantity_last_hour  \
# 0                              -0.4345                            -0.5477
# 1                              -0.4344                            -0.5459
# 2                               0.5216                             0.5253
# 3                              -0.4310                            -0.4811
# 4                              -0.2378                            -0.3132
#
#    store__returns_quantity_rescanned_frac  \
# 0                                 -0.3301
# 1                                  0.4436
# 2                                 -0.1531
# 3                                 -0.3301
# 4                                 -0.3301
#
#    store__gift_returns_quantity_last_hour  region__n_stores  \
# 0                                 -0.2948           -0.6658
# 1                                 -0.2948           -0.7599
# 2                                 -0.1990            1.4968
# 3                                 -0.2948           -0.7834
# 4                                 -0.2645           -0.7834
#
#    region__n_open_registers  region__mean_service_time_per_customer  \
# 0                   -0.6307                                 -0.1320
# 1                   -0.7220                                  0.8413
# 2                    1.0070                                 -0.3185
# 3                   -0.7220                                  0.8032
# 4                   -0.7220                                  0.9011
#
#    region__stdev_service_time_per_customer  \
# 0                                   0.3398
# 1                                   0.1972
# 2                                  -0.4461
# 3                                   0.1548
# 4                                   0.1806
#
#    region__sales_dollar_amt_last_hour  region__returns_dollar_amt_last_hour  \
# 0                             -0.6373                               -0.3791
# 1                             -0.6483                               -0.4419
# 2                              0.6712                                0.3971
# 3                             -0.6653                               -0.4437
# 4                             -0.6495                               -0.4418
#
#    region__nighttime_open_registers  \
# 0                           -0.5581
# 1                           -0.6498
# 2                            2.0094
# 3                           -0.6498
# 4                           -0.6498
#
#    region__nighttime_service_time_per_customer  \
# 0                                      -0.7148
# 1                                       0.8867
# 2                                       0.0464
# 3                                       0.8937
# 4                                       0.9006
#
#    region__nighttime_sales_amt_per_hour  \
# 0                               -0.6487
# 1                               -0.6493
# 2                                1.8275
# 3                               -0.6493
# 4                               -0.6493
#
#    region__nighttime_returns_amt_per_hour  \
# 0                                 -0.6091
# 1                                 -0.6106
# 2                                  2.0689
# 3                                 -0.6106
# 4                                 -0.6106
#
#    region__peak_sales_dollar_amt_per_hour  \
# 0                                  1.0020
# 1                                 -1.9779
# 2                                  0.0332
# 3                                  0.4998
# 4                                  0.4998
#
#    region__peak_sales_dollar_amt_per_hour_v2  \
# 0                                    -0.5479
# 1                                    -0.9816
# 2                                     1.3795
# 3                                    -0.9816
# 4                                    -0.9816
#
#    region__peak_returns_dollar_amt_per_hour  \
# 0                                    0.8761
# 1                                   -0.1311
# 2                                   -0.3489
# 3                                    0.8939
# 4                                    0.8939
#
#    region__peak_returns_dollar_amt_per_hour_v2
# 0                                          NaN
# 1                                      -0.8614
# 2                                       1.3382
# 3                                      -0.8614
# 4                                      -0.8614

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5179 entries, 0 to 5178
# Data columns (total 61 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   observation_id                               5179 non-null   object
#  1   observation_timestamp                        5179 non-null   object
#  2   hour_of_day                                  5179 non-null   int64
#  3   register__payment_types_accepted             5179 non-null   object
#  4   register__peak_sales_dollar_amt_per_hour     5179 non-null   float64
#  5   register__sales_dollar_amt_last_hour         5179 non-null   float64
#  6   register__sales_quantity_last_hour           5179 non-null   float64
#  7   register__sales_quantity_rescanned_frac      5179 non-null   float64
#  8   register__sales_payments_declined_frac       5179 non-null   float64
#  9   register__peak_returns_dollar_amt_per_hour   5179 non-null   float64
#  10  register__returns_dollar_amt_last_hour       5179 non-null   float64
#  11  register__returns_quantity_last_hour         5179 non-null   float64
#  12  register__returns_quantity_rescanned_frac    5179 non-null   float64
#  13  cashier__title_level                         5179 non-null   float64
#  14  cashier__n_years_experience                  5179 non-null   float64
#  15  cashier__hours_into_shift                    5179 non-null   float64
#  16  cashier__item_scan_rate_per_min              5179 non-null   float64
#  17  cashier__item_manual_entry_rate_per_min      5179 non-null   float64
#  18  store__type_code                             5179 non-null   object
#  19  store__miles_to_nearest_location             5179 non-null   float64
#  20  store__target_sales_quantity_per_hour        5179 non-null   float64
#  21  store__mean_customer_to_staff_ratio          5179 non-null   float64
#  22  store__mean_service_time_per_customer        5179 non-null   float64
#  23  store__n_employees_total                     5179 non-null   float64
#  24  store__n_managers                            5179 non-null   float64
#  25  store__n_baggers                             5179 non-null   float64
#  26  store__n_open_registers                      5179 non-null   float64
#  27  store__is_sufficiently_staffed               5179 non-null   float64
#  28  store__occupancy_main_floor                  5179 non-null   float64
#  29  store__occupancy_grocery                     5179 non-null   float64
#  30  store__occupancy_checkout_areas              5179 non-null   float64
#  31  store__occupancy_food_court                  5179 non-null   float64
#  32  store__occupancy_backrooms                   5179 non-null   float64
#  33  store__occupancy_indoors                     5179 non-null   float64
#  34  store__occupancy_outdoors                    5179 non-null   float64
#  35  store__outdoor_temperature                   5179 non-null   float64
#  36  store__parking_lot_utilization               5179 non-null   float64
#  37  store__shelf_freespace_frac                  5179 non-null   float64
#  38  store__hrs_since_last_delivery               5179 non-null   float64
#  39  store__sales_dollar_amt_last_hour            5179 non-null   float64
#  40  store__sales_quantity_last_hour              5179 non-null   float64
#  41  store__sales_quantity_rescanned_frac         5179 non-null   float64
#  42  store__gift_sales_quantity_last_hour         5179 non-null   float64
#  43  store__returns_dollar_amt_last_hour          5179 non-null   float64
#  44  store__returns_quantity_last_hour            5179 non-null   float64
#  45  store__returns_quantity_rescanned_frac       5179 non-null   float64
#  46  store__gift_returns_quantity_last_hour       5179 non-null   float64
#  47  region__n_stores                             5179 non-null   float64
#  48  region__n_open_registers                     5179 non-null   float64
#  49  region__mean_service_time_per_customer       5179 non-null   float64
#  50  region__stdev_service_time_per_customer      5179 non-null   float64
#  51  region__sales_dollar_amt_last_hour           5179 non-null   float64
#  52  region__returns_dollar_amt_last_hour         5179 non-null   float64
#  53  region__nighttime_open_registers             5179 non-null   float64
#  54  region__nighttime_service_time_per_customer  5179 non-null   float64
#  55  region__nighttime_sales_amt_per_hour         5179 non-null   float64
#  56  region__nighttime_returns_amt_per_hour       5179 non-null   float64
#  57  region__peak_sales_dollar_amt_per_hour       5179 non-null   float64
#  58  region__peak_sales_dollar_amt_per_hour_v2    5079 non-null   float64
#  59  region__peak_returns_dollar_amt_per_hour     5179 non-null   float64
#  60  region__peak_returns_dollar_amt_per_hour_v2  4611 non-null   float64
# dtypes: float64(56), int64(1), object(4)
# memory usage: 2.4+ MB

# %% [markdown]
# **Checking missing values**

# %%
train.isna().any().any(), test.isna().any().any()
# Out:
# (True, True)

# %% [markdown]
# *region__peak_sales_dollar_amt_per_hour_v2* and *region__peak_returns_dollar_amt_per_hour_v2* have missing values in both datasets.
# However, these are the experimental features in the dataset which are not supposed to be used. Thus, we can simply drop these columns instead of imputing the missing values.

# %% [markdown]
# **Dropping useless column**

# %%
train = train.drop(
    labels=[
        'Unnamed: 0', 
        'region__peak_sales_dollar_amt_per_hour_v2', 
        'region__peak_returns_dollar_amt_per_hour_v2'
    ], 
    axis=1
)

test = test.drop(
    labels=[
        'region__peak_sales_dollar_amt_per_hour_v2', 
        'region__peak_returns_dollar_amt_per_hour_v2'
    ], 
    axis=1
)

# %% [markdown]
# # Target

# %%
TARGET = 'register__sales_dollar_amt_this_hour'

# %%
train[TARGET].min(), train[TARGET].max()
# Out:
# (15.71, 4978.65)

# %% [markdown]
# # Features
# [Data dictionary](https://docs.google.com/spreadsheets/d/1a_Zw27zQfEZF_GnDqXuoYnoOiyrgOcasw0DIUTAhrr4/edit#gid=1521074975)

# %% [markdown]
# ### observation_id

# %%
train.shape[0], train['observation_id'].nunique()
# Out:
# (18512, 18512)

# %%
test.shape[0], test['observation_id'].nunique()
# Out:
# (5179, 5179)

# %%
set(train['observation_id'].unique()).intersection(set(test['observation_id'].unique()))
# Out:
# set()

# %% [markdown]
# Definitely a unique identifier. Can be dropped from feature set for modeling.

# %%
train = train.drop(labels='observation_id', axis=1)
test = test.drop(labels='observation_id', axis=1)

# %% [markdown]
# ### hour_of_day

# %%
train['hour_of_day'].min(), train['hour_of_day'].max()
# Out:
# (0, 23)

# %%
test['hour_of_day'].min(), test['hour_of_day'].max()
# Out:
# (0, 23)

# %% [markdown]
# ### observation_timestamp

# %%
train[['observation_timestamp', 'hour_of_day']].sample(5, random_state=SEED)
# Out:
#       observation_timestamp  hour_of_day
# 8125    2022-06-04 07:12:50            7
# 17419   2022-05-21 20:50:26           20
# 1859    2022-05-16 21:22:43           21
# 14474   2022-05-21 01:52:23            1
# 12401   2022-05-17 20:49:20           20

# %%
train['observation_timestamp'] = pd.to_datetime(train['observation_timestamp'])
test['observation_timestamp'] = pd.to_datetime(test['observation_timestamp'])

# %%
train.observation_timestamp.min(), train.observation_timestamp.max()
# Out:
# (Timestamp('2022-04-07 21:46:33'), Timestamp('2022-07-29 21:15:48'))

# %%
test.observation_timestamp.min(), test.observation_timestamp.max()
# Out:
# (Timestamp('2022-01-06 00:04:00'), Timestamp('2022-12-05 23:56:00'))

# %%
len(test.loc[(test.observation_timestamp > '2022-04-07 21:46:33') 
             & (test.observation_timestamp < '2022-07-29 21:15:48')])
# Out:
# 3594

# %% [markdown]
# * Train dataset records only cover early April to late July 2022, while Test dataset records cover early January to early December 2022.
# We have training data for summer sales but it cannot help predict winter sales.
# * However, 3594 out of 5178 test dataset records fall within our train data range. Thus, there is still some value in the timestamp data.

# %%
train['month'] = train.observation_timestamp.dt.month.astype('int')
test['month'] = test.observation_timestamp.dt.month.astype('int')

# %%
train['day'] = train.observation_timestamp.dt.day.astype('int')
test['day'] = test.observation_timestamp.dt.day.astype('int')

# %%
train['day_of_week'] = train.observation_timestamp.dt.day_of_week.astype('int')
test['day_of_week'] = test.observation_timestamp.dt.day_of_week.astype('int')

# %% [markdown]
# ### object columns

# %%
train.describe(include='O').T
# Out:
#                                   count unique          top   freq
# register__payment_types_accepted  18512      3  Cash+Credit  16310
# store__type_code                  18512      6            A  11691

# %% [markdown]
# #### register__payment_types_accepted

# %%
train.register__payment_types_accepted.value_counts(normalize=True)
# Out:
# Cash+Credit          0.8811
# Cash+Credit+Check    0.1152
# Credit               0.0037
# Name: register__payment_types_accepted, dtype: float64

# %%
test.register__payment_types_accepted.value_counts(normalize=True)
# Out:
# Cash+Credit          0.8828
# Cash+Credit+Check    0.1128
# Credit               0.0044
# Name: register__payment_types_accepted, dtype: float64

# %% [markdown]
# #### store__type_code

# %%
train.store__type_code.value_counts(normalize=True)
# Out:
# A    0.6315
# C    0.3045
# B    0.0465
# D    0.0171
# F    0.0003
# E    0.0001
# Name: store__type_code, dtype: float64

# %%
test.store__type_code.value_counts(normalize=True)
# Out:
# A    0.6584
# C    0.2807
# B    0.0423
# D    0.0180
# F    0.0004
# E    0.0002
# Name: store__type_code, dtype: float64

# %% [markdown]
# #### Encoding:

# %%
train['register__payment_types_accepted'] = train['register__payment_types_accepted'].astype('category')
test['register__payment_types_accepted'] = test['register__payment_types_accepted'].astype('category')

train['store__type_code'] = train['store__type_code'].astype('category')
test['store__type_code'] = test['store__type_code'].astype('category')

# %% [markdown]
# ### numerical columns

# %%
train.describe(include=['float64']).T
# Out:
#                                                count       mean       std  \
# register__sales_dollar_amt_this_hour         18512.0  1169.8142  818.4552
# register__peak_sales_dollar_amt_per_hour     18512.0     0.0029    1.0075
# register__sales_dollar_amt_last_hour         18512.0     0.0005    1.1195
# register__sales_quantity_last_hour           18512.0     0.0012    1.1134
# register__sales_quantity_rescanned_frac      18512.0    -0.0144    0.9885
# register__sales_payments_declined_frac       18512.0     0.0015    1.0371
# register__peak_returns_dollar_amt_per_hour   18512.0     0.0067    1.0104
# register__returns_dollar_amt_last_hour       18512.0     0.0031    1.1070
# register__returns_quantity_last_hour         18512.0     0.0026    1.1109
# register__returns_quantity_rescanned_frac    18512.0    -0.0242    0.9607
# cashier__title_level                         18512.0    -0.0018    1.0055
# cashier__n_years_experience                  18512.0    -0.0204    1.0003
# cashier__hours_into_shift                    18512.0     0.0059    0.9928
# cashier__item_scan_rate_per_min              18512.0    -0.0012    1.0071
# cashier__item_manual_entry_rate_per_min      18512.0    -0.0014    1.0089
# store__miles_to_nearest_location             18512.0     0.0300    0.9774
# store__target_sales_quantity_per_hour        18512.0    -0.0227    0.9170
# store__mean_customer_to_staff_ratio          18512.0     0.0007    1.0094
# store__mean_service_time_per_customer        18512.0     0.0161    1.0025
# store__n_employees_total                     18512.0    -0.0118    0.9978
# store__n_managers                            18512.0     0.0025    1.0044
# store__n_baggers                             18512.0     0.0084    1.0092
# store__n_open_registers                      18512.0     0.0141    1.0064
# store__is_sufficiently_staffed               18512.0    -0.0441    0.9500
# store__occupancy_main_floor                  18512.0     0.0028    1.0031
# store__occupancy_grocery                     18512.0     0.0059    0.9975
# store__occupancy_checkout_areas              18512.0    -0.0265    0.9676
# store__occupancy_food_court                  18512.0    -0.0009    0.9950
# store__occupancy_backrooms                   18512.0    -0.0048    0.9944
# store__occupancy_indoors                     18512.0    -0.0024    1.0022
# store__occupancy_outdoors                    18512.0    -0.0215    0.9814
# store__outdoor_temperature                   18512.0    -0.0303    0.9864
# store__parking_lot_utilization               18512.0    -0.0230    0.9969
# store__shelf_freespace_frac                  18512.0    -0.0309    0.9841
# store__hrs_since_last_delivery               18512.0    -0.0101    0.9962
# store__sales_dollar_amt_last_hour            18512.0     0.0024    1.0112
# store__sales_quantity_last_hour              18512.0     0.0027    1.0127
# store__sales_quantity_rescanned_frac         18512.0     0.0005    1.1036
# store__gift_sales_quantity_last_hour         18512.0    -0.0275    0.9752
# store__returns_dollar_amt_last_hour          18512.0    -0.0018    1.0062
# store__returns_quantity_last_hour            18512.0    -0.0003    1.0112
# store__returns_quantity_rescanned_frac       18512.0     0.0069    1.0100
# store__gift_returns_quantity_last_hour       18512.0    -0.0041    0.9717
# region__n_stores                             18512.0     0.0144    1.0105
# region__n_open_registers                     18512.0     0.0174    1.0081
# region__mean_service_time_per_customer       18512.0     0.0210    0.9915
# region__stdev_service_time_per_customer      18512.0     0.0063    0.9975
# region__sales_dollar_amt_last_hour           18512.0     0.0178    1.0155
# region__returns_dollar_amt_last_hour         18512.0     0.0070    1.0396
# region__nighttime_open_registers             18512.0     0.0148    1.0056
# region__nighttime_service_time_per_customer  18512.0     0.0217    0.9788
# region__nighttime_sales_amt_per_hour         18512.0     0.0184    1.0070
# region__nighttime_returns_amt_per_hour       18512.0     0.0155    1.0056
# region__peak_sales_dollar_amt_per_hour       18512.0    -0.0190    0.9964
# region__peak_returns_dollar_amt_per_hour     18512.0     0.0086    1.0083
#
#                                                  min       25%        50%  \
# register__sales_dollar_amt_this_hour         15.7100  369.1600  1165.7950
# register__peak_sales_dollar_amt_per_hour     -0.9858   -0.6241    -0.3357
# register__sales_dollar_amt_last_hour         -0.1270   -0.1267    -0.1250
# register__sales_quantity_last_hour           -0.1994   -0.1976    -0.1686
# register__sales_quantity_rescanned_frac      -0.8299   -0.7678    -0.3684
# register__sales_payments_declined_frac       -0.1247   -0.1247    -0.1247
# register__peak_returns_dollar_amt_per_hour   -0.5852   -0.5251    -0.5251
# register__returns_dollar_amt_last_hour       -0.2582   -0.2580    -0.2475
# register__returns_quantity_last_hour         -0.2621   -0.2591    -0.2047
# register__returns_quantity_rescanned_frac    -0.5337   -0.5248    -0.3982
# cashier__title_level                         -2.6036   -0.3520    -0.3520
# cashier__n_years_experience                  -2.5371   -0.7454    -0.7454
# cashier__hours_into_shift                    -0.7183   -0.6161    -0.3474
# cashier__item_scan_rate_per_min              -3.6181   -0.7330     0.0913
# cashier__item_manual_entry_rate_per_min      -6.9310   -0.5733     0.2605
# store__miles_to_nearest_location             -2.6524    0.1973     0.1973
# store__target_sales_quantity_per_hour        -7.1044   -0.1846     0.0019
# store__mean_customer_to_staff_ratio          -1.6296   -0.9231    -0.2166
# store__mean_service_time_per_customer        -1.2206   -0.5413    -0.0421
# store__n_employees_total                     -2.9041   -0.2960    -0.2960
# store__n_managers                            -0.9381   -0.3657    -0.3657
# store__n_baggers                             -0.6371   -0.6371     0.1657
# store__n_open_registers                      -0.7536   -0.7536    -0.4057
# store__is_sufficiently_staffed               -0.3909   -0.3909    -0.3909
# store__occupancy_main_floor                  -0.6463   -0.6353    -0.5347
# store__occupancy_grocery                     -0.8492   -0.6439    -0.4037
# store__occupancy_checkout_areas              -0.4386   -0.4386    -0.3467
# store__occupancy_food_court                  -0.8841   -0.6946    -0.2865
# store__occupancy_backrooms                   -0.1812   -0.1664    -0.1138
# store__occupancy_indoors                     -1.0063   -0.7917    -0.3723
# store__occupancy_outdoors                    -0.7087   -0.5614    -0.2571
# store__outdoor_temperature                   -2.2797   -0.8211     0.0128
# store__parking_lot_utilization               -1.2242   -1.0458     0.0643
# store__shelf_freespace_frac                  -4.9265   -0.3931    -0.1341
# store__hrs_since_last_delivery               -1.1804   -0.4964    -0.2153
# store__sales_dollar_amt_last_hour            -0.5493   -0.5483    -0.5200
# store__sales_quantity_last_hour              -0.5959   -0.5897    -0.5020
# store__sales_quantity_rescanned_frac         -0.0124   -0.0124    -0.0124
# store__gift_sales_quantity_last_hour         -0.4119   -0.4113    -0.3785
# store__returns_dollar_amt_last_hour          -0.4345   -0.4325    -0.4132
# store__returns_quantity_last_hour            -0.5477   -0.5322    -0.3974
# store__returns_quantity_rescanned_frac       -0.3301   -0.3301    -0.3293
# store__gift_returns_quantity_last_hour       -0.2948   -0.2948    -0.2191
# region__n_stores                             -0.7834   -0.7599    -0.6658
# region__n_open_registers                     -0.7257   -0.7111    -0.6160
# region__mean_service_time_per_customer       -1.2743   -0.5707    -0.2326
# region__stdev_service_time_per_customer      -0.5214   -0.4678    -0.4303
# region__sales_dollar_amt_last_hour           -0.6934   -0.6493    -0.4586
# region__returns_dollar_amt_last_hour         -0.4618   -0.4418    -0.2295
# region__nighttime_open_registers             -0.6498   -0.6441    -0.5581
# region__nighttime_service_time_per_customer  -1.4229   -0.7372     0.0477
# region__nighttime_sales_amt_per_hour         -0.6493   -0.6493    -0.6471
# region__nighttime_returns_amt_per_hour       -0.6106   -0.6105    -0.6037
# region__peak_sales_dollar_amt_per_hour       -2.2592   -0.4209     0.0332
# region__peak_returns_dollar_amt_per_hour     -2.3370   -0.3489    -0.3080
#
#                                                    75%        max
# register__sales_dollar_amt_this_hour         1457.4875  4978.6500
# register__peak_sales_dollar_amt_per_hour        0.4694     6.0216
# register__sales_dollar_amt_last_hour           -0.0885   146.3522
# register__sales_quantity_last_hour             -0.0206   141.5132
# register__sales_quantity_rescanned_frac         0.3613     7.8503
# register__sales_payments_declined_frac         -0.1247    55.3798
# register__peak_returns_dollar_amt_per_hour     -0.0236     5.6865
# register__returns_dollar_amt_last_hour          0.0366   136.4912
# register__returns_quantity_last_hour            0.0419   139.6000
# register__returns_quantity_rescanned_frac      -0.0657     9.6933
# cashier__title_level                           -0.3520     1.8996
# cashier__n_years_experience                     1.0463     2.8380
# cashier__hours_into_shift                       0.1451     4.7001
# cashier__item_scan_rate_per_min                 0.9156     3.4916
# cashier__item_manual_entry_rate_per_min         0.7816     2.8660
# store__miles_to_nearest_location                0.4564     1.4927
# store__target_sales_quantity_per_hour           0.0641    15.4471
# store__mean_customer_to_staff_ratio             0.4899    22.3919
# store__mean_service_time_per_customer           0.3466    24.9221
# store__n_employees_total                        0.9549     1.3797
# store__n_managers                               0.2068     4.7867
# store__n_baggers                                0.1657     4.9823
# store__n_open_registers                         0.2900     3.7686
# store__is_sufficiently_staffed                 -0.3909     2.5582
# store__occupancy_main_floor                     0.1429     8.1481
# store__occupancy_grocery                        0.2479    10.7828
# store__occupancy_checkout_areas                 0.0540    13.5189
# store__occupancy_food_court                     0.3357    13.2036
# store__occupancy_backrooms                      0.0012    44.4159
# store__occupancy_indoors                        0.4914     5.2243
# store__occupancy_outdoors                       0.1308    15.6547
# store__outdoor_temperature                      0.6376     5.0136
# store__parking_lot_utilization                  0.9885     3.0908
# store__shelf_freespace_frac                     0.5136     7.2489
# store__hrs_since_last_delivery                  0.1716     6.7210
# store__sales_dollar_amt_last_hour               0.1081    14.6529
# store__sales_quantity_last_hour                 0.0924    12.3424
# store__sales_quantity_rescanned_frac           -0.0124   147.5135
# store__gift_sales_quantity_last_hour           -0.0257    12.6635
# store__returns_dollar_amt_last_hour            -0.0918    18.3395
# store__returns_quantity_last_hour               0.0221    15.0990
# store__returns_quantity_rescanned_frac         -0.2656     5.3438
# store__gift_returns_quantity_last_hour         -0.0023    33.7121
# region__n_stores                                1.4968     5.2344
# region__n_open_registers                        1.2154     2.5058
# region__mean_service_time_per_customer          0.7366    15.7335
# region__stdev_service_time_per_customer         0.1280     6.1084
# region__sales_dollar_amt_last_hour              0.4497     9.3384
# region__returns_dollar_amt_last_hour            0.2959    19.8816
# region__nighttime_open_registers                0.3474     2.1699
# region__nighttime_service_time_per_customer     0.8869    11.5375
# region__nighttime_sales_amt_per_hour            0.9242     1.8275
# region__nighttime_returns_amt_per_hour          0.3280     2.0689
# region__peak_sales_dollar_amt_per_hour          0.4998     3.6141
# region__peak_returns_dollar_amt_per_hour        0.8939     2.4046

# %% [markdown]
# * A lot of negative values where we would not expect them. For instance, median 'sales_dollar_amount_last_hour' is negative. We would expect any kind of sales amount to be non-negative.
# * Except the target variable, the other numerical columns have zero mean and unit std. deviation, which means they are preprocessed (standardized). Thus, we cannot derive any insights from the original data. We can only do further preprocessing such as outlier removal for sensitive algorithms.

# %% [markdown]
# # Baseline

# %%
features = list(test.columns)
features.remove('observation_timestamp')

# %%
def regression_accuracy(y_meas, y_pred, max_error=20, error_type='relative'):
    '''Compares predicted & measured values, returning the percentage of predictions
       that are within a set error limit. This error limit can be an absolute value
       or a relative percentage'''

    # OPTION 1: Relative percentage
    if ( error_type == 'relative' ):
        mask = 100.0 * abs((y_pred - y_meas) / y_meas) < max_error

    # OPTION 2: Absolute value
    if ( error_type == 'absolute' ):
        mask = abs(y_pred - y_meas) < max_error

    accuracy = sum(mask) / len(mask)

    return -accuracy # '-' for xgboost eval-metric usage

# %%
# %%time
scores_racc = []
scores_mae = []
test_preds = []

X = train[features]
y = train[TARGET]

baseline = XGBRegressor(
    n_estimators=1000,
    learning_rate = 0.02,
    max_depth=10,
    tree_method='gpu_hist',
    enable_categorical=True,
    max_cat_to_onehot=6,
    predictor='gpu_predictor',
    eval_metric=regression_accuracy,
    early_stopping_rounds=50,
    seed=SEED
)

cv = KFold(n_splits=5, shuffle=True, random_state=SEED)
for fold, (train_idx, val_idx) in enumerate(cv.split(X, y)):
    X_train, y_train = X.loc[train_idx], y.iloc[train_idx]
    X_val, y_val = X.loc[val_idx], y.iloc[val_idx]
    baseline.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=50
    )
    preds_val = baseline.predict(X_val)
    racc = regression_accuracy(y_val, preds_val)
    scores_racc.append(racc)
    mae = mean_absolute_error(y_val, preds_val)
    scores_mae.append(mae)
    test_preds.append(baseline.predict(test[features]))
    print(f'Fold #{fold}: R-Acc = {racc:.5f}, MAE = {mae:.5f}')

print(f'\nAvg. R-Acc = {np.mean(scores_racc):.5f} +/- {np.std(scores_racc):.5f}')
print(f'Avg. MAE = {np.mean(scores_mae):.5f} +/- {np.std(scores_mae):.5f}')
# Out:
# [0]	validation_0-rmse:1402.60286	validation_0-regression_accuracy:-0.00000
# [50]	validation_0-rmse:548.05768	validation_0-regression_accuracy:-0.05887
# [100]	validation_0-rmse:266.91579	validation_0-regression_accuracy:-0.78396
# [150]	validation_0-rmse:195.50707	validation_0-regression_accuracy:-0.86335
# [200]	validation_0-rmse:180.72904	validation_0-regression_accuracy:-0.86660
# [218]	validation_0-rmse:179.51492	validation_0-regression_accuracy:-0.86633
# Fold #0: R-Acc = -0.86821, MAE = 112.67949
# [0]	validation_0-rmse:1397.52647	validation_0-regression_accuracy:-0.00000
# [50]	validation_0-rmse:552.52304	validation_0-regression_accuracy:-0.06940
# [100]	validation_0-rmse:284.57429	validation_0-regression_accuracy:-0.78396
# [150]	validation_0-rmse:225.57809	validation_0-regression_accuracy:-0.86740
# [200]	validation_0-rmse:215.18215	validation_0-regression_accuracy:-0.86740
# [226]	validation_0-rmse:213.34882	validation_0-regression_accuracy:-0.86740
# Fold #1: R-Acc = -0.87011, MAE = 113.21467
# [0]	validation_0-rmse:1405.69693	validation_0-regression_accuracy:-0.00000
# [50]	validation_0-rmse:549.40752	validation_0-regression_accuracy:-0.06672
# [100]	validation_0-rmse:272.23632	validation_0-regression_accuracy:-0.78228
# [150]	validation_0-rmse:202.46332	validation_0-regression_accuracy:-0.86386
# [200]	validation_0-rmse:189.10050	validation_0-regression_accuracy:-0.86359
# [216]	validation_0-rmse:187.83572	validation_0-regression_accuracy:-0.86413
# Fold #2: R-Acc = -0.86521, MAE = 113.10338
# [0]	validation_0-rmse:1378.12676	validation_0-regression_accuracy:-0.00000
# [50]	validation_0-rmse:536.71062	validation_0-regression_accuracy:-0.07374
# [100]	validation_0-rmse:260.00845	validation_0-regression_accuracy:-0.78444
# [150]	validation_0-rmse:189.99061	validation_0-regression_accuracy:-0.85224
# [200]	validation_0-rmse:177.67012	validation_0-regression_accuracy:-0.85981
# [250]	validation_0-rmse:175.12459	validation_0-regression_accuracy:-0.85737
# [257]	validation_0-rmse:175.05619	validation_0-regression_accuracy:-0.85683
# Fold #3: R-Acc = -0.86035, MAE = 99.74313
# [0]	validation_0-rmse:1413.26388	validation_0-regression_accuracy:-0.00000
# [50]	validation_0-rmse:553.50032	validation_0-regression_accuracy:-0.06024
# [100]	validation_0-rmse:281.09908	validation_0-regression_accuracy:-0.77202
# [150]	validation_0-rmse:219.68031	validation_0-regression_accuracy:-0.85981
# [200]	validation_0-rmse:209.70480	validation_0-regression_accuracy:-0.85926
# [227]	validation_0-rmse:208.21348	validation_0-regression_accuracy:-0.85899
# Fold #4: R-Acc = -0.86251, MAE = 116.04403
#
# Avg. R-Acc = -0.86528 +/- 0.00358
# Avg. MAE = 110.95694 +/- 5.73236
# CPU times: user 1min 49s, sys: 201 ms, total: 1min 50s
# Wall time: 1min 49s

# %%
preds_df = pd.DataFrame(np.column_stack(test_preds), columns=[f'Fold_{i}' for i in range(5)])
preds_df
# Out:
#          Fold_0     Fold_1     Fold_2     Fold_3     Fold_4
# 0     1716.9926  1684.6437  1705.6852  1764.9753  1798.0679
# 1      352.2997   352.0203   351.2715   357.1324   350.3503
# 2     1368.2958  1375.0820  1361.2714  1410.5143  1376.3406
# 3      297.1163   290.6902   274.1450   301.2448   279.4444
# 4      348.9647   353.2632   349.1398   356.0157   354.6789
# ...         ...        ...        ...        ...        ...
# 5174  1021.2933  1096.0903  1088.5035  1072.3995  1116.0011
# 5175  1081.6003  1273.4852  1225.4816  1248.3768  1211.2305
# 5176   849.8782   839.8718   842.3035   800.8390   816.1514
# 5177  1076.7432  1084.7090  1245.8694  1016.5651  1061.3091
# 5178   963.0385   979.0117   951.7444   994.8226   985.0449
#
# [5179 rows x 5 columns]

# %%
sub_1 = pd.DataFrame({'prediction': preds_df['Fold_1']})
sub_1.to_csv('01_sub_1.csv', index=False)

# %%
sub_0 = pd.DataFrame({'prediction': preds_df['Fold_0']})
sub_0.to_csv('01_sub_0.csv', index=False)

# %%
avg_preds = np.mean(np.column_stack(test_preds), axis=1)

# %%
sub_avg = pd.DataFrame({'prediction': avg_preds})
sub_avg.to_csv('01_sub_avg.csv', index=False)
